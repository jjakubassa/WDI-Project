# %%
import pandas as pd

df = pd.read_csv('../../../data/output/debugResultsDatafusion_recordLevel.csv')
df.head()
# Out:
#             RecordIDS  AverageConsistency  Genre-Consistency  \
# 0   MB_26616+spy_4485            1.000000                1.0
# 1  MB_66953+spy_10452            1.000000                1.0
# 2  MB_70673+WDC_26251            0.818182                1.0
# 3   MB_41162+WDC_1061            0.909091                1.0
# 4  MB_43774+WDC_37035            0.818182                1.0
#
#                                         Genre-Values  Language-Consistency  \
# 0  {[]|[chinese singer-songwriter, mainland chine...                   1.0
# 1                        {[]|[scam rap, trap queen]}                   1.0
# 2                                            {[]|[]}                   1.0
# 3                                            {[]|[]}                   1.0
# 4                                            {[]|[]}                   1.0
#
#   Language-Values  Labels-Consistency                 Labels-Values  \
# 0           {zho}                 1.0                       {[]|[]}
# 1           {eng}                 1.0  {[Quality Control Music]|[]}
# 2           {eng}                 1.0        {[Capitol Records]|[]}
# 3           {eng}                 1.0                    {[RCA]|[]}
# 4           {eng}                 1.0   {[Warner Bros. Records]|[]}
#
#    Total Tracks-Consistency Total Tracks-Values  ...  Artist-Consistency  \
# 0                       1.0             {10|10}  ...                 1.0
# 1                       1.0             {16|16}  ...                 1.0
# 2                       0.0              {10|1}  ...                 0.0
# 3                       0.0             {14|15}  ...                 1.0
# 4                       0.0              {11|1}  ...                 0.0
#
#                                        Artist-Values  Duration-Consistency  \
# 0    {[[Artist: Ronghao Li]]|[[Artist: Ronghao Li]]}                   1.0
# 1    {[[Artist: City Girls]]|[[Artist: City Girls]]}                   1.0
# 2  {[[Artist: Deborah Allen]]|[[Artist: Rufus Wai...                   1.0
# 3    {[[Artist: Clay Aiken]]|[[Artist: Clay Aiken]]}                   1.0
# 4          {[[Artist: Earshot]]|[[Artist: Tantric]]}                   1.0
#
#   Duration-Values  Title-Consistency  \
# 0        {2176.0}                1.0
# 1        {1867.0}                1.0
# 2         {186.0}                1.0
# 3        {3631.0}                1.0
# 4         {177.0}                1.0
#
#                                         Title-Values  Tracks-Consistency  \
# 0                                            {模特|模特}                 1.0
# 1                                    {PERIOD|PERIOD}                 1.0
# 2          {Trouble in Paradise|Trouble In Paradise}                 1.0
# 3  {A Thousand Different Ways|A Thousand Differen...                 1.0
# 4                            {Letting Go|Letting Go}                 1.0
#
#                                        Tracks-Values  \
# 0  {[[Track: 老伴], [Track: 吩咐], [Track: 心声], [Trac...
# 1  {[[Track: Period (We Live)], [Track: De Period...
# 2                 {[[Track: 'Trouble In Paradise']]}
# 3  {[[Track: 'Broken Wings'], [Track: 'Everything...
# 4                          {[[Track: 'Letting Go']]}
#
#    Release Date-Consistency      Release Date-Values
# 0                       1.0  {2013-09-16|2013-09-16}
# 1                       1.0  {2018-05-11|2018-05-11}
# 2                       1.0             {1980-02-29}
# 3                       1.0             {2006-09-19}
# 4                       1.0             {2002-05-07}
#
# [5 rows x 24 columns]

# %%
# sort by longest value in RecordsIDS
df['Group size'] = df['RecordIDS'].str.split('+').apply(len)

# %%
df = df.sort_values(by=['Group size'], ascending=False)
df.head()
# Out:
#                                               RecordIDS  AverageConsistency  \
# 6159  MB_10435+MB_15480+MB_64976+WDC_10226+WDC_10368...            0.583877
# 4066  MB_16647+WDC_1062+WDC_10686+WDC_11464+WDC_1152...            0.754083
# 8757  MB_61024+WDC_1012+WDC_10241+WDC_11092+WDC_1148...            0.662279
# 7322  MB_11972+WDC_10279+WDC_11510+WDC_13530+WDC_141...            0.594177
# 1827  MB_10622+WDC_10978+WDC_11679+WDC_1383+WDC_1426...            0.593283
#
#       Genre-Consistency                                       Genre-Values  \
# 6159                1.0  {[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|...
# 4066                1.0  {[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|...
# 8757                1.0  {[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|...
# 7322                1.0  {[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|...
# 1827                1.0  {[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|...
#
#       Language-Consistency Language-Values  Labels-Consistency  \
# 6159                   1.0   {eng|eng|eng}                 1.0
# 4066                   1.0           {eng}                 1.0
# 8757                   1.0           {eng}                 1.0
# 7322                   1.0           {eng}                 1.0
# 1827                   1.0           {eng}                 1.0
#
#                                           Labels-Values  \
# 6159  {[]|[Sparrow Records]|[Asylum Records]|[]|[]|[...
# 4066  {[Geffen Records]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[...
# 8757  {[Hospital Records]|[]|[]|[]|[]|[]|[]|[]|[]|[]...
# 7322  {[MCA Nashville]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]...
# 1827  {[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|[]|...
#
#       Total Tracks-Consistency  \
# 6159                  0.233533
# 4066                  0.466667
# 8757                  0.403846
# 7322                  0.294118
# 1827                  0.303030
#
#                                     Total Tracks-Values  ...  \
# 6159  {14|12|12|17|19|21|50|18|14|16|10|19|18|20|17|...  ...
# 4066  {12|6|12|17|24|12|12|10|12|31|12|7|10|5|21|31|...  ...
# 8757  {10|25|12|12|23|25|20|25|19|10|12|25|10|25|25|...  ...
# 7322  {11|11|46|22|16|18|3|22|19|22|11|29|12|18|18|3...  ...
# 1827  {20|18|50|17|23|18|15|18|15|15|15|17|18|50|18|...  ...
#
#                                           Artist-Values Duration-Consistency  \
# 6159  {[[Artist: Dennis Brown]]|[[Artist: Michelle T...             0.469512
# 4066  {[[Artist: Hole]]|[[Artist: Lee Morgan]]|[[Art...             0.711864
# 8757  {[[Artist: High Contrast]]|[[Artist: Eddie Coc...             0.254902
# 7322  {[[Artist: George Strait]]|[[Artist: Josh Turn...             0.181818
# 1827  {[[Artist: Alanis Morissette]]|[[Artist: Del A...             0.625000
#
#                                         Duration-Values Title-Consistency  \
# 6159  {4450.0|4060.0|4793.0|11041.0|4999.0|3036.0|44...               1.0
# 4066  {2412.0|2134.0|3314.0|4237.0|1537.0|1766.0|146...               1.0
# 8757  {3275.0|1646.0|1745.0|3489.0|3725.0|2614.0|430...               1.0
# 7322  {2404.0|9365.0|4683.0|3989.0|4486.0|783.0|4683...               1.0
# 1827  {4485.0|7559.0|4469.0|4417.0|4500.0|3149.0|455...               1.0
#
#                                            Title-Values Tracks-Consistency  \
# 6159  {Greatest Hits|Greatest Hits|Greatest Hits|Gre...           0.048780
# 4066  {Live Through This|Live Through This|Live Thro...           0.118644
# 8757  {True Colours|True Colours|True Colours|True C...           0.058824
# 7322  {Best Of|Best Of|Best Of|Best Of|Best Of|Best ...           0.181818
# 1827  {The Collection|The Collection|The Collection|...           0.156250
#
#                                           Tracks-Values  \
# 6159  {[[Track: 'Lifted (Linslee 7\\' Mix)'], [Track...
# 4066  {[[Track: 'Latin Hangover'], [Track: 'D's Fink...
# 8757  {[[Track: 'Teresa'], [Track: 'Little Lou'], [T...
# 7322  {[[Track: 'Everything Is Fine (Album Version)'...
# 1827  {[[Track: 'Out Falls The Past (Album Version)'...
#
#      Release Date-Consistency  \
# 6159                      0.0
# 4066                      1.0
# 8757                      1.0
# 7322                      NaN
# 1827                      0.0
#
#                                     Release Date-Values Group size
# 6159  {1987-02-28|2008-04-11|2000-10-31|2008-01-01|2...        167
# 4066                                       {1994-04-21}         60
# 8757                                       {2002-10-28}         52
# 7322                                                NaN         34
# 1827                            {2005-11-14|1964-01-01}         33
#
# [5 rows x 25 columns]

# %%
for i in range(3, 4):
    df_group = pd.DataFrame()
    row = df.iloc[i]
    
    print(row["RecordIDS"].split('+'))
    print(row["Artist-Values"])
    print(row["Title-Values"])
    print()
# Out:
# ['MB_11972', 'WDC_10279', 'WDC_11510', 'WDC_13530', 'WDC_14139', 'WDC_14327', 'WDC_15622', 'WDC_15795', 'WDC_15911', 'WDC_19343', 'WDC_20068', 'WDC_2070', 'WDC_22211', 'WDC_24423', 'WDC_24440', 'WDC_25521', 'WDC_29529', 'WDC_29545', 'WDC_29677', 'WDC_30370', 'WDC_31005', 'WDC_31794', 'WDC_33088', 'WDC_3325', 'WDC_36433', 'WDC_36446', 'WDC_37762', 'WDC_4232', 'WDC_43514', 'WDC_5467', 'WDC_7130', 'WDC_7848', 'WDC_9381', 'WDC_9798']
# {[[Artist: George Strait]]|[[Artist: Josh Turner]]|[[Artist: The Cardigans]]|[[Artist: The Cardigans]]|[[Artist: Skid Row]]|[[Artist: Gilbert Montagné]]|[[Artist: Wang Chung]]|[[Artist: The Cardigans]]|[[Artist: Zebda]]|[[Artist: The Cardigans]]|[[Artist: George Strait]]|[[Artist: Kay Kyser]]|[[Artist: Snowstorm]]|[[Artist: Gilbert Montagné]]|[[Artist: Howard Jones]]|[[Artist: Manian]]|[[Artist: The Cardigans]]|[[Artist: Eddy Mitchell]]|[[Artist: Burning Spear]]|[[Artist: The Cardigans]]|[[Artist: Eddie Rabbitt]]|[[Artist: Billy Currington]]|[[Artist: Kay Kyser]]|[[Artist: Josh Turner]]|[[Artist: Cheek To Cheek]]|[[Artist: Zebda]]|[[Artist: Kay Kyser]]|[[Artist: The Cardigans]]|[[Artist: The Cardigans]]|[[Artist: Gilbert Montagné]]|[[Artist: Billy Currington]]|[[Artist: Wang Chung]]|[[Artist: Eddie Rabbitt]]|[[Artist: Josh Turner]]}
# {Best Of|Best Of|Best Of|Best Of|Best Of|Best Of|Best Of|Best Of|Best Of|Best Of|Best Of|Best of|Best Of|Best Of|Best Of|Best Of|Best Of|Best Of|Best Of|Best Of|Best Of|Best Of|Best of|Best Of|Best Of|Best Of|Best of|Best Of|Best Of|Best Of|Best Of|Best Of|Best Of|Best Of}
